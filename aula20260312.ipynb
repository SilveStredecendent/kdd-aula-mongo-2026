# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb://root:rootpass@mongo:27017")

# %% [markdown]
# Protocolo	mongodb://	O "idioma" que a aplicação vai usar para conversar com o banco.
#
# Usuário	root	A credencial de acesso (quem está tentando entrar).
#
# Senha	rootpass	A chave secreta desse usuário.
#
# Host	mongo	Onde o banco está rodando (pode ser um IP ou o nome de um container Docker).
#
# Porta	27017	A "porta" específica do servidor que o MongoDB está escutando.

# %%
db = client["loja"]
produtos = db["produtos"]

# %%
produtos.insert_many([
{"nome":"Mouse Logitech","categoria":"Informática","preco":120,"estoque":50,"avaliacoes":[4,4,5],"disponivel":True},
{"nome":"Teclado Mecânico","categoria":"Informática","preco":350,"estoque":20,"avaliacoes":[5,5,4],"disponivel":True},
{"nome":"Smartphone Samsung","categoria":"Celulares","preco":2200,"estoque":15,"avaliacoes":[5,4,4],"disponivel":True},
{"nome":"Smartphone Xiaomi","categoria":"Celulares","preco":1800,"estoque":0,"avaliacoes":[4,4,4],"disponivel":False},
{"nome":"Fone Bluetooth","categoria":"Acessórios","preco":250,"estoque":30,"avaliacoes":[4,3,4],"disponivel":True},
{"nome":"Monitor LG","categoria":"Informática","preco":1200,"estoque":8,"avaliacoes":[5,5,5],"disponivel":True},
{"nome":"Carregador USB-C","categoria":"Acessórios","preco":80,"estoque":40,"avaliacoes":[4,4,3],"disponivel":True},
{"nome":"Tablet Lenovo","categoria":"Tablets","preco":1500,"estoque":5,"avaliacoes":[4,5,4],"disponivel":True},
{"nome":"Smartwatch Xiaomi","categoria":"Wearables","preco":900,"estoque":12,"avaliacoes":[4,4,5],"disponivel":True}
])
# Out:
# InsertManyResult([ObjectId('69b362f7d941cc63cd30d585'), ObjectId('69b362f7d941cc63cd30d586'), ObjectId('69b362f7d941cc63cd30d587'), ObjectId('69b362f7d941cc63cd30d588'), ObjectId('69b362f7d941cc63cd30d589'), ObjectId('69b362f7d941cc63cd30d58a'), ObjectId('69b362f7d941cc63cd30d58b'), ObjectId('69b362f7d941cc63cd30d58c'), ObjectId('69b362f7d941cc63cd30d58d')], acknowledged=True)

# %%
for item in produtos.find():
    print(item)
# Out:
# {'_id': ObjectId('69b36283d941cc63cd30d583')}
# {'_id': ObjectId('69b36298d941cc63cd30d584')}
# {'_id': ObjectId('69b362f7d941cc63cd30d585'), 'nome': 'Mouse Logitech', 'categoria': 'Informática', 'preco': 120, 'estoque': 50, 'avaliacoes': [4, 4, 5], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d586'), 'nome': 'Teclado Mecânico', 'categoria': 'Informática', 'preco': 350, 'estoque': 20, 'avaliacoes': [5, 5, 4], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d587'), 'nome': 'Smartphone Samsung', 'categoria': 'Celulares', 'preco': 2200, 'estoque': 15, 'avaliacoes': [5, 4, 4], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d588'), 'nome': 'Smartphone Xiaomi', 'categoria': 'Celulares', 'preco': 1800, 'estoque': 0, 'avaliacoes': [4, 4, 4], 'disponivel': False}
# {'_id': ObjectId('69b362f7d941cc63cd30d589'), 'nome': 'Fone Bluetooth', 'categoria': 'Acessórios', 'preco': 250, 'estoque': 30, 'avaliacoes': [4, 3, 4], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d58a'), 'nome': 'Monitor LG', 'categoria': 'Informática', 'preco': 1200, 'estoque': 8, 'avaliacoes': [5, 5, 5], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d58b'), 'nome': 'Carregador USB-C', 'categoria': 'Acessórios', 'preco': 80, 'estoque': 40, 'avaliacoes': [4, 4, 3], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d58c'), 'nome': 'Tablet Lenovo', 'categoria': 'Tablets', 'preco': 1500, 'estoque': 5, 'avaliacoes': [4, 5, 4], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d58d'), 'nome': 'Smartwatch Xiaomi', 'categoria': 'Wearables', 'preco': 900, 'estoque': 12, 'avaliacoes': [4, 4, 5], 'disponivel': True}

# %%
for item in produtos.find({"preco" : {"$gt" : 500}}):
    print(item)
# Out:
# {'_id': ObjectId('69b362f7d941cc63cd30d587'), 'nome': 'Smartphone Samsung', 'categoria': 'Celulares', 'preco': 2200, 'estoque': 15, 'avaliacoes': [5, 4, 4], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d588'), 'nome': 'Smartphone Xiaomi', 'categoria': 'Celulares', 'preco': 1800, 'estoque': 0, 'avaliacoes': [4, 4, 4], 'disponivel': False}
# {'_id': ObjectId('69b362f7d941cc63cd30d58a'), 'nome': 'Monitor LG', 'categoria': 'Informática', 'preco': 1200, 'estoque': 8, 'avaliacoes': [5, 5, 5], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d58c'), 'nome': 'Tablet Lenovo', 'categoria': 'Tablets', 'preco': 1500, 'estoque': 5, 'avaliacoes': [4, 5, 4], 'disponivel': True}
# {'_id': ObjectId('69b362f7d941cc63cd30d58d'), 'nome': 'Smartwatch Xiaomi', 'categoria': 'Wearables', 'preco': 900, 'estoque': 12, 'avaliacoes': [4, 4, 5], 'disponivel': True}

# %%
dados = list(produtos.find())
dados
# Out:
# [{'_id': ObjectId('69b36283d941cc63cd30d583')},
#  {'_id': ObjectId('69b36298d941cc63cd30d584')},
#  {'_id': ObjectId('69b362f7d941cc63cd30d585'),
#   'nome': 'Mouse Logitech',
#   'categoria': 'Informática',
#   'preco': 120,
#   'estoque': 50,
#   'avaliacoes': [4, 4, 5],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d586'),
#   'nome': 'Teclado Mecânico',
#   'categoria': 'Informática',
#   'preco': 350,
#   'estoque': 20,
#   'avaliacoes': [5, 5, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d587'),
#   'nome': 'Smartphone Samsung',
#   'categoria': 'Celulares',
#   'preco': 2200,
#   'estoque': 15,
#   'avaliacoes': [5, 4, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d588'),
#   'nome': 'Smartphone Xiaomi',
#   'categoria': 'Celulares',
#   'preco': 1800,
#   'estoque': 0,
#   'avaliacoes': [4, 4, 4],
#   'disponivel': False},
#  {'_id': ObjectId('69b362f7d941cc63cd30d589'),
#   'nome': 'Fone Bluetooth',
#   'categoria': 'Acessórios',
#   'preco': 250,
#   'estoque': 30,
#   'avaliacoes': [4, 3, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d58a'),
#   'nome': 'Monitor LG',
#   'categoria': 'Informática',
#   'preco': 1200,
#   'estoque': 8,
#   'avaliacoes': [5, 5, 5],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d58b'),
#   'nome': 'Carregador USB-C',
#   'categoria': 'Acessórios',
#   'preco': 80,
#   'estoque': 40,
#   'avaliacoes': [4, 4, 3],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d58c'),
#   'nome': 'Tablet Lenovo',
#   'categoria': 'Tablets',
#   'preco': 1500,
#   'estoque': 5,
#   'avaliacoes': [4, 5, 4],
#   'disponivel': True},
#  {'_id': ObjectId('69b362f7d941cc63cd30d58d'),
#   'nome': 'Smartwatch Xiaomi',
#   'categoria': 'Wearables',
#   'preco': 900,
#   'estoque': 12,
#   'avaliacoes': [4, 4, 5],
#   'disponivel': True}]

# %%
df_produtos = pd.DataFrame(dados)
df_produtos.head()
# Out:
#                         _id                nome    categoria   preco  estoque  \
# 0  69b36283d941cc63cd30d583                 NaN          NaN     NaN      NaN
# 1  69b36298d941cc63cd30d584                 NaN          NaN     NaN      NaN
# 2  69b362f7d941cc63cd30d585      Mouse Logitech  Informática   120.0     50.0
# 3  69b362f7d941cc63cd30d586    Teclado Mecânico  Informática   350.0     20.0
# 4  69b362f7d941cc63cd30d587  Smartphone Samsung    Celulares  2200.0     15.0
#
#   avaliacoes disponivel
# 0        NaN        NaN
# 1        NaN        NaN
# 2  [4, 4, 5]       True
# 3  [5, 5, 4]       True
# 4  [5, 4, 4]       True

# %%
df_produtos = df_produtos.drop(columns=["_id"])
df_produtos.head(3)
# Out:
#              nome    categoria  preco  estoque avaliacoes disponivel
# 0             NaN          NaN    NaN      NaN        NaN        NaN
# 1             NaN          NaN    NaN      NaN        NaN        NaN
# 2  Mouse Logitech  Informática  120.0     50.0  [4, 4, 5]       True

# %%
df_produtos["media_avaliacoes"] = df_produtos["avaliacoes"].apply(lambda x: sum(x)/len(x))
df_produtos.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_produtos["media_avaliacoes"] = df_produtos["avaliacoes"].apply(lambda x: sum(x)/len(x))
#       2 df_produtos.head(3)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/base.py:1022, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1019 if isinstance(arr, ExtensionArray):
#    1020     return arr.map(mapper, na_action=na_action)
# -> 1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[23], line 1, in <lambda>(x)
# ----> 1 df_produtos["media_avaliacoes"] = df_produtos["avaliacoes"].apply(lambda x: sum(x)/len(x))
#       2 df_produtos.head(3)
#
# TypeError: 'float' object is not iterable

# %%
produtos_p = db["produtos_processados"]

# %%
dados_p = df_produtos.to_dict("records")
dados_p

# %%
produtos_p.insert_many(dados_p)

# %%
for item in produtos_p.find():
    print(item)
